# %%
import numpy as np
import pandas as pd

# %%
path = 'ecomm-open-cdp/items_ohe_2019_oct.csv'
df = pd.read_csv(path)

# %%
df.to_parquet('items_ohe_2019_oct.parquet')

# %%
df2 = pd.read_parquet('ecomm-open-cdp/items_ohe_2019_oct.parquet')

# %%
df2.head()dd
# Out:
#    Unnamed: 0  accessories.bag  accessories.umbrella  accessories.wallet  \
# 0           0            False                 False               False
# 1           1            False                 False               False
# 2           2            False                 False               False
# 3           3            False                 False               False
# 4           4            False                 False               False
#
#    apparel.belt  apparel.costume  apparel.dress  apparel.jacket  \
# 0         False            False          False           False
# 1         False            False          False           False
# 2         False            False          False           False
# 3         False            False          False           False
# 4         False            False          False           False
#
#    apparel.jeans  apparel.jumper  ...  kids.skates  kids.swing  kids.toys  \
# ...
